# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()

# %% [markdown]
# look nbs in this repo and add them to nbs requirement in the nbdev
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Let me explore the repo structure first to see what notebooks exist and how the nbdev setup is configured.
#
#
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;find . -name \&quot;*.ipynb\&quot; -type f | sort&quot;)→&quot;./00_core.ipynb\n./01_data.ipynb\n./02_mod…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_3FjXLFhMOigbgMqbaYjR2011",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "find . -name \"*.ipynb\" -type f | sort"
#     }
#   },
#   "result": "./00_core.ipynb\n./01_data.ipynb\n./02_model.ipynb\n./03_learner.ipynb\n./index.ipynb"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;ls -la&quot;)→&quot;total 788\ndrwxrwsr-x 3 solveit solveit  …&quot;</code></summary>
#
# ```json
# {
#   "id": "call_01_4hSz4rCguBq9XrLRoHAy4991",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "ls -la"
#     }
#   },
#   "result": "total 788\ndrwxrwsr-x 3 solveit solveit   4096 Jul 21 14:59 .\ndrwxrwsr-x 7 solveit solveit   4096 Jul 21 12:54 ..\n-rw------- 1 solveit solveit   1297 Jul 21 14:59 00_core.ipynb\n-rw------- 1 solveit solveit  41068 Jul 21 14:05 01_data.ipynb\n-rw------- 1 solveit solveit 388330 Jul 21 14:12 02_model.ipynb\n-rw------- 1 solveit solveit  25188 Jul 21 14:12 03_learner.ipynb\n-rw-rw-r-- 1 solveit solveit    330 Jul 21 12:54 _quarto.yml\n-rw------- 1 solveit solveit 312067 Jul 21 13:56 index.ipynb\ndrwxrwsr-x 2 solveit solveit   4096 Jul 21 13:06 ml-100k\n-rw-rw-r-- 1 solveit solveit    214 Jul 21 12:54 nbdev.yml\n-rw-rw-r-- 1 solveit solveit    600 Jul  5 03:22 styles.css"
# }
# ```
#
# </details>
#
#
#
#
#
# Let me check the nbdev config and see what's in the notebooks:
#
#
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;cat nbdev.yml&quot;)→&quot;project:\n  output-dir: _docs\n\nwebsite:\n …&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_oO2QEjH81dp7cXt2NO2n4747",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "cat nbdev.yml"
#     }
#   },
#   "result": "project:\n  output-dir: _docs\n\nwebsite:\n  title: \"fastpragma\"\n  site-url: \"https://risheekkumarb.github.io/fastpragma\"\n  description: \"\"\n  repo-branch: main\n  repo-url: \"https://github.com/risheekkumarb/fastpragma\""
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;cat _quarto.yml&quot;)→&quot;project:\n  type: website\n\nformat:\n  html…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_01_jelBiV1j4tDBo1wjcpwW6942",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "cat _quarto.yml"
#     }
#   },
#   "result": "project:\n  type: website\n\nformat:\n  html:\n    theme: cosmo\n    css: styles.css\n    toc: true\n    keep-md: true\n  commonmark: default\n\nwebsite:\n  twitter-card: true\n  open-graph: true\n  repo-actions: [issue]\n  navbar:\n    background: primary\n    search: true\n  sidebar:\n    style: floating\n\nmetadata-files: [nbdev.yml, sidebar.yml]"
# }
# ```
#
# </details>
#
#
#
#
#
#
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;cat sidebar.yml 2&gt;/dev/null || echo \&quot;No …&quot;)→&quot;PermissionError: /dev/null. Code message…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_eu28FoEf8BSUEQkRa52R1303",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "cat sidebar.yml 2>/dev/null || echo \"No sidebar.yml found\""
#     }
#   },
#   "result": "PermissionError: /dev/null. Code message has been added to dialog. Ask user to run it."
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;for f in 00_core.ipynb 01_data.ipynb 02_…&quot;)→&quot;Traceback (most recent call last):\n  Fil…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_01_Zf4k6SqKjbhLt3fed50r6837",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "for f in 00_core.ipynb 01_data.ipynb 02_model.ipynb 03_learner.ipynb index.ipynb; do echo \"=== $f ===\"; python -c \"import json; d=json.load(open('$f')); [print(c['source'][0] if c.get('source') else '') for c in d['cells'][:3]]\"; echo; done"
#     }
#   },
#   "result": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/site-packages/toolslm/funccall.py\", line 276, in call_func_async\n    res = await maybe_await(res)\n          ^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/site-packages/fastcore/xtras.py\", line 1079, in maybe_await\n    return await o if isawaitable(o) else o\n           ^^^^^^^\n  File \"/root/solveit/solveit/aimsg.py\", line 234, in _f\n    await tmsg.exec(set_current=False)\n  File \"/root/solveit/solveit/runloop.py\", line 33, in exec\n    if self.msg_type==scode: await self.exec_code()\n                             ^^^^^^^^^^^^^^^^^^^^^^\n  File \"/root/solveit/solveit/kernel.py\", line 181, in exec_code\n    await self.dlg.kc.reply(self.content, msg_id=mid)\n  File \"/usr/local/lib/python3.12/site-packages/conkernelclient/core.py\", line 107, in _async_recv_reply\n    if isinstance(res, Exception): raise res\n                                   ^^^^^^^^^\nRuntimeError: Kernel error aborted: DisallowedDest: /dev/null"
# }
# ```
#
# </details>
#
#
#
#
#
# Here's what I found so far:
#
# **Notebooks in the repo:**
# - `00_core.ipynb`
# - `01_data.ipynb`
# - `02_model.ipynb`
# - `03_learner.ipynb`
# - `index.ipynb`
#
# **Current nbdev config:** The `nbdev.yml` has project metadata and website settings, but no `nbs` section listing which notebooks to include.
#
# In nbdev, there are a couple of ways to specify which notebooks get processed — typically through a `sidebar.yml` or directly in the nbdev config. I wasn't able to read `sidebar.yml` due to a permission issue on the redirect.
#
# How would you like the notebooks listed? For example, should the chapters section look like this in `nbdev.yml`:
#
# ```yaml
# chapters:
#   - index
#   - 00_core
#   - 01_data
#   - 02_model
#   - 03_learner
# ```
#
# Or do you prefer a different structure? Let me know and I'll make the edit.

# %% [markdown]
# make sure all the requirements of these notebooks are in the requirements for this repo
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Let me look at the imports from each notebook and check what requirements files already exist.
#
#
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;ls -la requirements*.txt settings.ini py…&quot;)→&quot;PermissionError: /dev/null. Code message…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_1P9vpVrX2XV5XELKfhDj3100",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "ls -la requirements*.txt settings.ini pyproject.toml setup.py 2>/dev/null || echo \"No requirements files found\""
#     }
#   },
#   "result": "PermissionError: /dev/null. Code message has been added to dialog. Ask user to run it."
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;find . -maxdepth 1 -type f | sort&quot;)→&quot;./00_core.ipynb\n./01_data.ipynb\n./02_mod…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_01_drd21x66R7RNfKUOkPB37944",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "find . -maxdepth 1 -type f | sort"
#     }
#   },
#   "result": "./00_core.ipynb\n./01_data.ipynb\n./02_model.ipynb\n./03_learner.ipynb\n./_quarto.yml\n./index.ipynb\n./nbdev.yml\n./styles.css"
# }
# ```
#
# </details>
#
#
#
#
#
# The repo doesn't have a `requirements.txt` or any other requirements file yet. Let me extract all the imports from each notebook to see what packages are needed.
#
# <｜｜DSML｜｜tool_calls>
# <｜｜DSML｜｜invoke name="bash">
# <｜｜DSML｜｜parameter name="cmd" string="true">for f in 00_core.ipynb 01_data.ipynb 02_model.ipynb 03_learner.ipynb index.ipynb; do echo "=== $f ==="; grep -oP '(?:import|from)\s+(\w+)' "$f" | sort -u; done</｜｜DSML｜｜parameter>
# </｜｜DSML｜｜invoke>
# </｜｜DSML｜｜tool_calls>

# %% [markdown]
# its a nbdev3 repo. you need to add the requirements to pyproject
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Let me check the imports and look for a pyproject.toml.
#
#
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;find . -name \&quot;pyproject.toml\&quot; -maxdepth …&quot;)→&quot;PermissionError: /dev/null. Code message…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_ET_u6mEl9RvDHVv7Oqg8znU0949",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "find . -name \"pyproject.toml\" -maxdepth 3 2>/dev/null"
#     }
#   },
#   "result": "PermissionError: /dev/null. Code message has been added to dialog. Ask user to run it."
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;ls -la *.toml 2&gt;/dev/null; ls -la */pypr…&quot;)→&quot;PermissionError: /dev/null. Code message…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_01_ET_2LNSs5Az50yLzsMp0aVC7080",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "ls -la *.toml 2>/dev/null; ls -la */pyproject.toml 2>/dev/null"
#     }
#   },
#   "result": "PermissionError: /dev/null. Code message has been added to dialog. Ask user to run it."
# }
# ```
#
# </details>
#
#
#
#
#
# I'm hitting permission issues with `/dev/null` redirects. Let me try a different approach to find the pyproject.toml and extract imports.
#
# <｜｜DSML｜｜tool_calls>
# <｜｜DSML｜｜invoke name="bash">
# <｜｜DSML｜｜parameter name="cmd" string="true">find . -name "pyproject.toml" -print -maxdepth 3</｜｜DSML｜｜parameter>
# </｜｜DSML｜｜invoke>
# </｜｜DSML｜｜tool_calls>

# %%
# %%bash
# ls -la *.toml 2>/dev/null; ls -la ../pyproject.toml 2>/dev/null
# Out:
# -rw-rw-r-- 1 solveit solveit 807 Jul 21 14:56 ../pyproject.toml

# %% [markdown]
# there it is
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;cat ../pyproject.toml&quot;)→&quot;[build-system]\nrequires = [\&quot;setuptools&gt;=…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_6MSKeezc3x2AbhvJ1mtJ6712",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "cat ../pyproject.toml"
#     }
#   },
#   "result": "[build-system]\nrequires = [\"setuptools>=64\"]\nbuild-backend = \"setuptools.build_meta\"\n\n[project]\nname = \"fastpragma\"\ndynamic = [\"version\"]\ndescription = \"\"\nreadme = \"README.md\"\nrequires-python = \">=3.10\"\nlicense = {text = \"Apache-2.0\"}\nauthors = [{name = \"Risheek kumar B\", email = \"b.risheekkumar@gmail.com\"}]\nkeywords = ['nbdev']\nclassifiers = [\n    \"Programming Language :: Python :: 3\",\n    \"Programming Language :: Python :: 3 :: Only\",\n]\ndependencies = []\n\n[project.urls]\nRepository = \"https://github.com/risheekkumarb/fastpragma\"\nDocumentation = \"https://risheekkumarb.github.io/fastpragma/\"\n\n[project.entry-points.nbdev]\nfastpragma = \"fastpragma._modidx:d\"\n\n[tool.setuptools.dynamic]\nversion = {attr = \"fastpragma.__version__\"}\n\n[tool.setuptools.packages.find]\ninclude = [\"fastpragma\"]\n\n[tool.nbdev]"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>bash(cmd=&quot;for f in 00_core.ipynb 01_data.ipynb 02_…&quot;)→&quot;=== 00_core.ipynb ===\nfrom each\nfrom nbd…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_01_OtiL7Nxtd0xIoJit80Au5182",
#   "server": false,
#   "call": {
#     "function": "bash",
#     "arguments": {
#       "cmd": "for f in 00_core.ipynb 01_data.ipynb 02_model.ipynb 03_learner.ipynb index.ipynb; do echo \"=== $f ===\"; grep -oP '(?:import|from)\\s+(\\w+)' \"$f\" | sort -u; done"
#     }
#   },
#   "result": "=== 00_core.ipynb ===\nfrom each\nfrom nbdev\nimport json\nimport nbdev\n=== 01_data.ipynb ===\nfrom Unix\nfrom auto\nfrom collections\nfrom dataclasses\nfrom fastcore\nimport dataclass\nimport defaultdict\nimport polars\nimport test_eq\n=== 02_model.ipynb ===\nfrom 10M\nfrom None\nfrom Su\nfrom Unix\nfrom a\nfrom auto\nfrom collections\nfrom data\nfrom dataclasses\nfrom dialoghelper\nfrom embeddings\nfrom fastai\nfrom fastcore\nfrom first\nfrom forward\nfrom history\nfrom index\nfrom inspect\nfrom low\nfrom note\nfrom raw\nfrom real\nfrom return_mlm\nfrom rgapi\nfrom scipy\nfrom sklearn\nfrom text\nfrom the\nfrom timestamps\nfrom tokenized\nimport LogisticRegression\nimport StandardScaler\nimport ad\nimport add_msg\nimport dataclass\nimport defaultdict\nimport fd\nimport isawaitable\nimport math\nimport minimize\nimport ms\nimport msg_exhash\nimport msg_lnhashview\nimport polars\nimport re\nimport read_msgid\nimport test_eq\nimport torch\nimport up\nimport update_msg\nimport vi\nimport view_dlg\n=== 03_learner.ipynb ===\nfrom fastai\nfrom fastcore\nfrom forward\nfrom low\nfrom return_mlm\nfrom scipy\nfrom sklearn\nfrom the\nimport LogisticRegression\nimport minimize\nimport test_eq\nimport torch\n=== index.ipynb ===\nfrom 10\nfrom 10M\nfrom 2023\nfrom 26\nfrom 943\nfrom None\nfrom September\nfrom Su\nfrom Time\nfrom a\nfrom all\nfrom both\nfrom broad\nfrom collections\nfrom complete\nfrom conda\nfrom dataclasses\nfrom dialoghelper\nfrom different\nfrom dt\nfrom dtypes\nfrom epoch\nfrom fastai\nfrom fastcore\nfrom fastpragma\nfrom full\nfrom images\nfrom index\nfrom inspect\nfrom irregular\nfrom long\nfrom minimal\nfrom modelling\nfrom multiple\nfrom nbdev\nfrom obsolete\nfrom overfitting\nfrom pathlib\nfrom pypi\nfrom pyskills\nfrom rating\nfrom raw\nfrom real\nfrom running\nfrom sample\nfrom scipy\nfrom scratch\nfrom sklearn\nfrom specialised\nfrom text\nfrom the\nfrom this\nfrom time_col\nfrom training\nfrom transactional\nfrom transformer\nfrom tuples\nfrom underfitting\nimport LogisticRegression\nimport Path\nimport StandardScaler\nimport ad\nimport add_msg\nimport cr\nimport create_or_run_dialog\nimport dataclass\nimport de\nimport defaultdict\nimport del_msg\nimport fastpragma\nimport file_create\nimport httpx\nimport isawaitable\nimport json\nimport li\nimport list_dialogs\nimport math\nimport minimize\nimport nbdev\nimport os\nimport polars\nimport test_eq\nimport torch\nimport up\nimport update_msg\nimport vi\nimport view_dlg\nimport zipfile"
# }
# ```
#
# </details>
#
#
#
#
#
# Good, now I have a clear picture. Here's what I found:
#
# **Current `pyproject.toml`** has `dependencies = []` — it's empty.
#
# **Third-party packages actually imported** across the 5 notebooks:
#
# | Package | Used in |
# |---|---|
# | `polars` | 01_data, 02_model, index |
# | `torch` | 02_model, 03_learner, index |
# | `fastai` | 02_model, 03_learner, index |
# | `fastcore` | 01_data, 02_model, 03_learner, index |
# | `scipy` | 02_model, 03_learner, index |
# | `scikit-learn` | 02_model, 03_learner, index |
# | `httpx` | index |
# | `nbdev` | 00_core, index |
# | `dialoghelper` | 02_model, index |
# | `rgapi` | 02_model |
# | `pyskills` | index |
#
# So the `dependencies` should look something like:
#
# ```toml
# dependencies = [
#     "polars",
#     "torch",
#     "fastai",
#     "fastcore",
#     "scipy",
#     "scikit-learn",
#     "httpx",
#     "nbdev",
#     "dialoghelper",
#     "rgapi",
#     "pyskills",
# ]
# ```
#
# Do any of these need minimum version pins that you're aware of? Otherwise I'm ready to add this list to `../pyproject.toml`.

# %% [markdown]
# yep add there deps there
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>python(code=&quot;import exhash.skill; doc(exhash.skill)&quot;)→&quot;# module exhash.skill:\n\n\&quot;\&quot;\&quot;Universal has…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_0VCrUoxavS2NVdKjVySK8341",
#   "server": false,
#   "call": {
#     "function": "python",
#     "arguments": {
#       "code": "import exhash.skill; doc(exhash.skill)"
#     }
#   },
#   "result": "# module exhash.skill:\n\n\"\"\"Universal hash-verified text editing for local files. Use this when an LLM needs one safe editing interface for reading, previewing, and modifying text files.\n\nExhash's purpose is to make edits precise and auditable. First view a file as ``lineno|hash|text``; then issue ex-style commands against those exact addresses. Every addressed line's hash is checked immediately before the command runs, so stale context or wrong targets fail instead of editing nearby text. Hashes are checked immediately before each command and lines shift as edits apply; for multiple edits in one call always work *backwards* (bottom-to-top).\n\nPrefer exhash over ad hoc patching for text file modifications. Use shell tools for discovery, tests, git, directory operations, and binary files.\n\nCore APIs:\n- ``lnhashview_file(path, start=None, end=None)`` (or the lnhash_cat helper) lists hashed lines.\n- ``exhash(text, cmds, sw=4)`` is the in-memory command engine; run ``doc(exhash)`` for complete command syntax.\n- ``exhash_file(path, cmds, sw=4, inplace=False)`` is the file-aware engine;\n  unqualified addresses use ``path`` and file-qualified addresses can edit or transfer across files.\n\nWorkflow:\n1. ``lnhash_cat(path, start=..., end=...))``.\n2. Copy exact displayed ``lineno|hash|`` addresses.\n3. Use raw triple-quoted strings and one exhash command per list item.\n4. Use ``exhash_file(path, cmds, inplace=True)`` to write and return diff.\n\nAddressing:\n  Commands use lnhash addresses: lineno|hash| where hash is a 4-char\n  hex content hash. Use lnhashview to get addresses:\n    lnhashview file.txt          show all lines with addresses\n    lnhashview file.txt 10 20    show lines 10-20\n  With multiple commands, hashes are checked immediately before each command runs.\n\n  Single:   12|a3f2|cmd\n  Range:    12|a3f2|,15|b1c3|cmd\n  Special:  0|0000| targets before line 1 (only with a or i)\n\nCommands:\n  s/pat/rep/[flags]  Substitute (regex). Flags: g=all, i=case-insensitive\n  d                  Delete line(s)\n  a[text]           Append inline text after line, or read following text block\n  i[text]           Insert inline text before line, or read following text block\n  c[text]           Change/replace with inline text, or read following text block\n  j                  Join with next line; with range, joins all lines in range\n  m dest             Move line(s) after dest address\n  t dest             Copy line(s) after dest address\n  >[n]               Indent n levels (default 1, 4 spaces each)\n  <[n]               Dedent n levels (default 1)\n  sort               Sort lines alphabetically\n  p                  Print (include lines in output without changing them)\n  g/pat/cmd          Global: run cmd on matching lines\n  g!/pat/cmd         Inverted global: run cmd on non-matching lines\n  v/pat/cmd          Same as g!\n\nImportant:\nDo not create addresses by text search or remembered line numbers. On stale hash, re-view and rebuild. For multiline ``a``/``i``/``c`` commands, put all text in one command string; text after the command character is the first inserted line and following newline-separated lines continue the block. For moving/copying across files, use file-qualified ``m``/``t`` commands; cross-file source ranges are invalid. Missing files can only be created through ``0|0000|`` creation semantics.\n\"\"\"\n\n## functions:\n- def line_hash(line: str) -> str: ...  # Return a 4-char lowercase hex hash for a single line of text.\n- def lnhash(lineno: int, line: str) -> str: ...  # Return an lnhash address ``lineno|hash|`` for ``line`` at 1-based ``lineno``.\n- def lnhashview(text: str, start: int = None, end: int = None) -> list[str]: ...  # Return lines formatted as ``lineno|hash|content``. Optional 1-based ``start``/``end`` filter the range; ``end`` past EOF is clamped.\n- def lnhashview_file(path: str, start: int = None, end: int = None) -> list[str]: ...  # Return lines formatted as ``lineno|hash|content`` for file at ``path``. Optional 1-based ``start``/``end`` filter the range; ``end`` past EOF is clamped.\n- def exhash(text: str, cmds: list[str], sw: int = 4): ...  # Verified line-addressed editor. Apply commands to `text`, return an EditResult.\n- def exhash_file(path: str, cmds: list[str], sw: int = 4, inplace: bool = False): ...  # Read files, apply file-aware exhash commands, and return per-file results or a combined diff.\n- def lnhash_cat(fname: str, start: int = None, end: int = None): ...  # Little shortcut for printing concatenated lines of lnhashview_file"
# }
# ```
#
# </details>
#
#
#
#
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>python(code=&quot;from exhash.skill import lnhash_cat\nprin…&quot;)→&quot;1|3df0|[build-system]\n2|44e6|requires = …&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_sWWCI1pv6ex7kI3FGTol9621",
#   "server": false,
#   "call": {
#     "function": "python",
#     "arguments": {
#       "code": "from exhash.skill import lnhash_cat\nprint(lnhash_cat('../pyproject.toml'))"
#     }
#   },
#   "result": "1|3df0|[build-system]\n2|44e6|requires = [\"setuptools>=64\"]\n3|b8e0|build-backend = \"setuptools.build_meta\"\n4|3def|\n5|5c20|[project]\n6|02f7|name = \"fastpragma\"\n7|e088|dynamic = [\"version\"]\n8|614b|description = \"\"\n9|1d2b|readme = \"README.md\"\n10|b1d7|requires-python = \">=3.10\"\n11|fab7|license = {text = \"Apache-2.0\"}\n12|79cb|authors = [{name = \"Risheek kumar B\", email = \"b.risheekkumar@gmail.com\"}]\n13|60b8|keywords = ['nbdev']\n14|dcb9|classifiers = [\n15|5e9b|    \"Programming Language :: Python :: 3\",\n16|584f|    \"Programming Language :: Python :: 3 :: Only\",\n17|1654|]\n18|fff1|dependencies = []\n19|3def|\n20|1b05|[project.urls]\n21|224c|Repository = \"https://github.com/risheekkumarb/fastpragma\"\n22|72b2|Documentation = \"https://risheekkumarb.github.io/fastpragma/\"\n23|3def|\n24|c370|[project.entry-points.nbdev]\n25|a920|fastpragma = \"fastpragma._modidx:d\"\n26|3def|\n27|a987|[tool.setuptools.dynamic]\n28|953c|version = {attr = \"fastpragma.__version__\"}\n29|3def|\n30|7df2|[tool.setuptools.packages.find]\n31|0e56|include = [\"fastpragma\"]\n32|3def|\n33|64e1|[tool.nbdev]\nNone"
# }
# ```
#
# </details>
#
#
#
#
#
#
#
# <details class='tool-usage-details' markdown='1'>
# <summary><code>python(code=&quot;from exhash.skill import exhash_file\npri…&quot;)→&quot;PermissionError: open &#x27;../pyproject.toml…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_00_oiiAtbHuiMVfCvDEy1173372",
#   "server": false,
#   "call": {
#     "function": "python",
#     "arguments": {
#       "code": "from exhash.skill import exhash_file\nprint(exhash_file('../pyproject.toml', [r'''18|fff1|cdependencies = [\n    \"polars\",\n    \"torch\",\n    \"fastai\",\n    \"fastcore\",\n    \"scipy\",\n    \"scikit-learn\",\n    \"httpx\",\n    \"nbdev\",\n    \"dialoghelper\",\n    \"rgapi\",\n    \"pyskills\",\n]'''], inplace=True))"
#     }
#   },
#   "result": "PermissionError: open '../pyproject.toml' not in (). Code message has been added to dialog. Ask user to run it."
# }
# ```
#
# </details>
#
#
#
#
#
# The edit failed — `exhash_file` doesn't allow writing to paths outside the current working directory. Let me use the full path from $`realpath()`.
#
# <｜｜DSML｜｜tool_calls>
# <｜｜DSML｜｜invoke name="python">
# <｜｜DSML｜｜parameter name="code" string="true">from exhash.skill import lnhash_cat
# path = '/app/data/create_pkg/fastpragma/pyproject.toml'
# print(lnhash_cat(path))</｜｜DSML｜｜parameter>
# </｜｜DSML｜｜invoke>
# </｜｜DSML｜｜tool_calls>

# %%
from exhash.skill import exhash_file
print(exhash_file('../pyproject.toml', [r'''18|fff1|cdependencies = [
    "polars",
    "torch",
    "fastai",
    "fastcore",
    "scipy",
    "scikit-learn",
    "httpx",
    "nbdev",
    "dialoghelper",
    "rgapi",
    "pyskills",
]'''], inplace=True))
# Out:
# --- ../pyproject.toml
# +++ ../pyproject.toml
#  17|1654|]
# -18|fff1|dependencies = []
# +18|17bd|dependencies = [
# +19|998f|    "polars",
# +20|ca27|    "torch",
# +21|2014|    "fastai",
# +22|b72a|    "fastcore",
# +23|7b67|    "scipy",
# +24|8344|    "scikit-learn",
# +25|f8bb|    "httpx",
# +26|52a8|    "nbdev",
# +27|cc6a|    "dialoghelper",
# +28|448a|    "rgapi",
# +29|e2e9|    "pyskills",
# +30|1654|]
#  31|3def|
